# %%
# Import and run dataset generation
import sys
sys.path.append('./scripts')

import generate_datasets
# generate_datasets.main()
# Out:
# Generated ../public/datasets/circles.json with 500 points
# Generated ../public/datasets/blobs.json with 500 points
# Generated ../public/datasets/moons.json with 500 points
# Generated ../public/datasets/aniso.json with 498 points
# Generated ../public/datasets/random.json with 500 points
#
# Generated 5 datasets in ../public/datasets/
# Processing circles (500 points)...
#   Generated k=2 -> ../public/clustering-results/kmeans/circles_k2.json
#   Generated k=3 -> ../public/clustering-results/kmeans/circles_k3.json
#   Generated k=4 -> ../public/clustering-results/kmeans/circles_k4.json
#   Generated k=5 -> ../public/clustering-results/kmeans/circles_k5.json
#   Generated k=6 -> ../public/clustering-results/kmeans/circles_k6.json
#   Generated k=7 -> ../public/clustering-results/kmeans/circles_k7.json
#   Generated k=8 -> ../public/clustering-results/kmeans/circles_k8.json
# Processing blobs (500 points)...
#   Generated k=2 -> ../public/clustering-results/kmeans/blobs_k2.json
# ...

# %%
# Import and run KMEans clustering
import generate_kmeans

algorithm = "kmeans"
import os
os.makedirs('./../public/datasets', exist_ok=True)
os.makedirs(f'./../public/clustering-results/{algorithm}', exist_ok=True)


generate_kmeans.main()

print("Datasets:", os.listdir("./../public/datasets"))
print(f"{algorithm} results:", len(os.listdir(f"./../public/clustering-results/{algorithm}")), "files")
# Out:
# Processing circles (500 points)...
#   Generated k=2 -> ../public/clustering-results/kmeans/circles_k2.json
#   Generated k=3 -> ../public/clustering-results/kmeans/circles_k3.json
#   Generated k=4 -> ../public/clustering-results/kmeans/circles_k4.json
#   Generated k=5 -> ../public/clustering-results/kmeans/circles_k5.json
#   Generated k=6 -> ../public/clustering-results/kmeans/circles_k6.json
#   Generated k=7 -> ../public/clustering-results/kmeans/circles_k7.json
#   Generated k=8 -> ../public/clustering-results/kmeans/circles_k8.json
# Processing blobs (500 points)...
#   Generated k=2 -> ../public/clustering-results/kmeans/blobs_k2.json
#   Generated k=3 -> ../public/clustering-results/kmeans/blobs_k3.json
#   Generated k=4 -> ../public/clustering-results/kmeans/blobs_k4.json
#   Generated k=5 -> ../public/clustering-results/kmeans/blobs_k5.json
#   Generated k=6 -> ../public/clustering-results/kmeans/blobs_k6.json
# ...

# %%
# Import and run DBSCAN clustering
import generate_dbscan

algorithm = "dbscan"
import os
os.makedirs('./../public/datasets', exist_ok=True)
os.makedirs(f'./../public/clustering-results/{algorithm}', exist_ok=True)


generate_dbscan.main()

print("Datasets:", os.listdir("./../public/datasets"))
print(f"{algorithm} results:", len(os.listdir(f"./../public/clustering-results/{algorithm}")), "files")
# Out:
# Generating DBSCAN results for 80 combinations...
#
# Processing dataset: circles
#   [1/80] eps=0.1, min_samples=3
#   [2/80] eps=0.1, min_samples=5
#   [3/80] eps=0.1, min_samples=8
#   [4/80] eps=0.1, min_samples=10
#   [5/80] eps=0.3, min_samples=3
#   [6/80] eps=0.3, min_samples=5
#   [7/80] eps=0.3, min_samples=8
#   [8/80] eps=0.3, min_samples=10
#   [9/80] eps=0.5, min_samples=3
#   [10/80] eps=0.5, min_samples=5
#   [11/80] eps=0.5, min_samples=8
#   [12/80] eps=0.5, min_samples=10
#   [13/80] eps=0.8, min_samples=3
#   [14/80] eps=0.8, min_samples=5
#   [15/80] eps=0.8, min_samples=8
#   [16/80] eps=0.8, min_samples=10
#   [17/80] eps=1.0, min_samples=3
#   [18/80] eps=1.0, min_samples=5
#   [19/80] eps=1.0, min_samples=8
#   [20/80] eps=1.0, min_samples=10
#
# Processing dataset: blobs
#   [21/80] eps=0.1, min_samples=3
#   [22/80] eps=0.1, min_samples=5
#   [23/80] eps=0.1, min_samples=8
#   [24/80] eps=0.1, min_samples=10
#   [25/80] eps=0.3, min_samples=3
# ...

# %%
# Import and run clustering
import generate_agglomerative

algorithm = "agglomerative"
import os
os.makedirs('./../public/datasets', exist_ok=True)
os.makedirs(f'./../public/clustering-results/{algorithm}', exist_ok=True)


generate_agglomerative.main()

print("Datasets:", os.listdir("./../public/datasets"))
print(f"{algorithm} results:", len(os.listdir(f"./../public/clustering-results/{algorithm}")), "files")
# Out:
# Generating Agglomerative results for 80 combinations...
#
# Processing dataset: circles
#   [1/80] k=2, linkage=ward
#   [2/80] k=2, linkage=complete
#   [3/80] k=2, linkage=average
#   [4/80] k=2, linkage=single
#   [5/80] k=3, linkage=ward
#   [6/80] k=3, linkage=complete
#   [7/80] k=3, linkage=average
#   [8/80] k=3, linkage=single
#   [9/80] k=4, linkage=ward
#   [10/80] k=4, linkage=complete
#   [11/80] k=4, linkage=average
#   [12/80] k=4, linkage=single
#   [13/80] k=5, linkage=ward
#   [14/80] k=5, linkage=complete
#   [15/80] k=5, linkage=average
#   [16/80] k=5, linkage=single
#   [17/80] k=6, linkage=ward
#   [18/80] k=6, linkage=complete
#   [19/80] k=6, linkage=average
#   [20/80] k=6, linkage=single
#
# Processing dataset: blobs
#   [21/80] k=2, linkage=ward
#   [22/80] k=2, linkage=complete
#   [23/80] k=2, linkage=average
#   [24/80] k=2, linkage=single
#   [25/80] k=3, linkage=ward
#   [26/80] k=3, linkage=complete
#   [27/80] k=3, linkage=average
# ...

# %%
# Import and run clustering
import generate_meanshift

algorithm = "meanshift"
import os
os.makedirs('./../public/datasets', exist_ok=True)
os.makedirs(f'./../public/clustering-results/{algorithm}', exist_ok=True)


generate_meanshift.main()

print("Datasets:", os.listdir("./../public/datasets"))
print(f"{algorithm} results:", len(os.listdir(f"./../public/clustering-results/{algorithm}")), "files")
# Out:
# Generating Mean Shift results for 24 combinations...
#
# Processing dataset: circles
#   [1/24] bandwidth=0.3
#   [2/24] bandwidth=0.5
#   [3/24] bandwidth=0.8
#   [4/24] bandwidth=1.0
#   [5/24] bandwidth=1.5
#   [6/24] bandwidth=2.0
#
# Processing dataset: blobs
#   [7/24] bandwidth=0.3
#   [8/24] bandwidth=0.5
#   [9/24] bandwidth=0.8
#   [10/24] bandwidth=1.0
#   [11/24] bandwidth=1.5
#   [12/24] bandwidth=2.0
#
# Processing dataset: moons
#   [13/24] bandwidth=0.3
#   [14/24] bandwidth=0.5
#   [15/24] bandwidth=0.8
#   [16/24] bandwidth=1.0
#   [17/24] bandwidth=1.5
#   [18/24] bandwidth=2.0
#
# Processing dataset: aniso
#   [19/24] bandwidth=0.3
#   [20/24] bandwidth=0.5
#   [21/24] bandwidth=0.8
#   [22/24] bandwidth=1.0
#   [23/24] bandwidth=1.5
#   [24/24] bandwidth=2.0
#
# Completed! Generated 24 result files in ../public/clustering-results/meanshift
# Datasets: ['moons.json', 'blobs.json', 'aniso.json', 'random.json', 'datasets.json', 'data.md', 'circles.json']
# ...

# %%
# Import and run clustering
import generate_gmm

algorithm = "gmm"
import os
os.makedirs('./../public/datasets', exist_ok=True)
os.makedirs(f'./../public/clustering-results/{algorithm}', exist_ok=True)


generate_gmm.main()

print("Datasets:", os.listdir("./../public/datasets"))
print(f"{algorithm} results:", len(os.listdir(f"./../public/clustering-results/{algorithm}")), "files")
# Out:
# Generating GMM results for 80 combinations...
#
# Processing dataset: circles
#   [1/80] k=2, cov=full
#   [2/80] k=2, cov=tied
#   [3/80] k=2, cov=diag
#   [4/80] k=2, cov=spherical
#   [5/80] k=3, cov=full
#   [6/80] k=3, cov=tied
#   [7/80] k=3, cov=diag
#   [8/80] k=3, cov=spherical
#   [9/80] k=4, cov=full
#   [10/80] k=4, cov=tied
#   [11/80] k=4, cov=diag
#   [12/80] k=4, cov=spherical
#   [13/80] k=5, cov=full
#   [14/80] k=5, cov=tied
#   [15/80] k=5, cov=diag
#   [16/80] k=5, cov=spherical
#   [17/80] k=6, cov=full
#   [18/80] k=6, cov=tied
#   [19/80] k=6, cov=diag
#   [20/80] k=6, cov=spherical
#
# Processing dataset: blobs
#   [21/80] k=2, cov=full
#   [22/80] k=2, cov=tied
#   [23/80] k=2, cov=diag
#   [24/80] k=2, cov=spherical
#   [25/80] k=3, cov=full
#   [26/80] k=3, cov=tied
#   [27/80] k=3, cov=diag
#   [28/80] k=3, cov=spherical
#   [29/80] k=4, cov=full
#   [30/80] k=4, cov=tied
#   [31/80] k=4, cov=diag
#   [32/80] k=4, cov=spherical
#   [33/80] k=5, cov=full
# ...
